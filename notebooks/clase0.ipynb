# %% [markdown]
# <a href="https://colab.research.google.com/github/RimDan/Intro-AA/blob/main/notebooks/clase0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 0 — Primeros pasos con Google Colab
#
# **Materia:** Introducción al Aprendizaje Automático
# **Alumno/a:** Escribí tu nombre aquí
# **Fecha:** Completar
#
# ## Objetivos
# En esta práctica vas a aprender a usar Google Colab y cuadernos `.ipynb`.
#
# ## Instrucciones generales
# - Leé cada consigna con atención.
# - Ejecutá las celdas cuando se indique.
# - Completá las respuestas en las celdas de texto o de código.
# - Guardá el cuaderno periódicamente.
# - Si una celda da error, no te preocupes: en esta práctica eso también forma parte del aprendizaje.

# %% [markdown]
# ## Actividad 1 — Ejecutar una celda
#
# **Consigna:**
# Ejecutá la siguiente celda de código usando el botón de “play” o con `Shift + Enter`.

# %%
print("Hola, mundo")

# %% [markdown]
# ## Actividad 2 — Modificar y volver a ejecutar
#
# **Consigna:**
# Cambiá el mensaje de la siguiente celda para que imprima tu nombre y tu carrera.
# Después, ejecutala nuevamente.

# %%
print("Me llamo ______ y estudio ______")

# %% [markdown]
# ## Actividad 3 — Variables
#
# En Python podemos guardar información en variables.
#
# **Consigna:**
# 1. Cambiá los valores de las variables por tus propios datos.
# 2. Ejecutá la celda.
# 3. Observá el resultado.

# %%
nombre = "Tu nombre"
edad = 20
materia = "Introducción al Aprendizaje Automático"

print("Nombre:", nombre)
print("Edad:", edad)
print("Materia:", materia)

# %% [markdown]
# ## Actividad 4 — Cálculos simples
#
# **Consigna:**
# Ejecutá la celda y después cambiá los valores de `a` y `b`.
# Probá con otros números.

# %%
a = 10
b = 3

print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)

# %% [markdown]
# ## Actividad 5 — Ver un error
#
# Los errores son normales al programar.
#
# **Consigna:**
# Ejecutá la siguiente celda sin corregir nada.
# Leé el mensaje que aparece.

# %%
print("Este mensaje no está cerrado")

# %% [markdown]
# **Consigna:**
# Corregí la celda para que funcione.

# %% [markdown]
# ## Actividad 6 — El orden importa
#
# En un cuaderno, el orden en que ejecutás las celdas afecta el resultado.
#
# **Consigna:**
# 1. Ejecutá primero la segunda celda.
# 2. Observá qué pasa.
# 3. Después ejecutá la primera celda y luego otra vez la segunda.

# %%
numero = 42

# %%
print("El valor de numero es:", numero)

# %% [markdown]
# ## Actividad 7 — Crear una celda de texto
#
# **Consigna:**
# Insertá una nueva celda de texto debajo de esta sección y escribí:
#
# - un título,
# - tu nombre,
# - una lista con 3 cosas que esperás aprender en la materia.
#
# **Ayuda:**
# Probá usar:
# - `#` para títulos
# - `-` para listas
# - `**texto**` para negrita

# %% [markdown]
# ## Actividad 8 — Repetir acciones con un bucle
#
# **Consigna:**
# Ejecutá la celda.
# Después, agregá un cuarto elemento a la lista y ejecutá de nuevo.

# %%
frutas = ["manzana", "banana", "naranja"]

for fruta in frutas:
    print("Me gusta la", fruta)

# %% [markdown]
# ## Actividad 9 — Usar una librería
#
# Google Colab permite usar librerías de Python.
#
# **Consigna:**
# Ejecutá la siguiente celda.

# %%
import math

print("Raíz cuadrada de 16:", math.sqrt(16))
print("Pi:", math.pi)

# %% [markdown]
# **Desafío:**
# Cambiá el 16 por 25, 49 y 81.

# %% [markdown]
# ## Actividad 10 — Primer gráfico
#
# **Consigna:**
# Ejecutá la celda y observá el gráfico.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Mi primer gráfico en Colab")
plt.show()

# %% [markdown]
# **Desafío:**
# Cambiá los valores de `y` y generá un gráfico distinto.

# %% [markdown]
# ## Actividad 11 — Subir un archivo a Colab
#
# **Consigna:**
# Ejecutá la siguiente celda y subí cualquier archivo pequeño desde tu computadora.

# %%
from google.colab import files

uploaded = files.upload()

# %% [markdown]
# **Pregunta:**
# Revisá dónde quedó disponible el archivo que subiste

# %% [markdown]
# ## Actividad 12 — Guardar y descargar
#
# **Consigna:**
# 1. Renombrá este cuaderno con tu apellido.
# 2. Verificá que se haya guardado en Google Drive.
# 3. Descargalo en formato `.ipynb`.
# 4. Descargalo también en formato `.pdf`.
